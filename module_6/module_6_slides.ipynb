# %% [markdown]
# # Session 6: Web Scraping 1
# *Hjalte Fejerskov Boas*

# %% [markdown]
# # About me
#
# - PhD student in Economics at UCPH
#     - At the moment: working on a project about cryptocurrencies and taxation
# - Master and bachelor from UCPH
# - Had this course in 2017
# - Taught the course in 2022
# - Personal website: https://www.hjalteboas.com/

# %% [markdown]
# ## Recap
# In session 5 you briefly touched upon extracting data from the internet
# - You heard about HTTP requests: The computer's way to communicate with the website and underlying server
# - You learned about HTML: The language behind a website
# - You worked with APIs: A way to retrieve structured data from websites
#     - You learned how to send requests to an API and in return receive the desired data
#     - You learned how to deal with the JSON files that is usually how the data is sent

# %% [markdown]
# In the next three sessions we will build on your newly acquired skills
#
# You will learn how to extract data from websites when no API is available
#
# It will open up a whole new world of data possibilities!

# %% [markdown]
# ## Required readings
#
# - [Beautiful Soup: Build a Web Scraper With Python](https://realpython.com/beautiful-soup-web-scraper-python/)
#
# - [A Practical Introduction to Web Scraping in Python](https://realpython.com/python-web-scraping-practical-introduction/)
#
# - Shiab, Nael. 2015. [On the Ethics of Web Scraping and Data Journalism](http://gijn.org/2015/08/12/on-the-ethics-of-web-scraping-and-data-journalism/). Global Investigative Journalism Network.

# %% [markdown]
# ## Overview of Session 6
#
# Today, we will learn about interacting with websites and extracting their unstructured data (web scraping). In particular, we will cover:
# 1. Basics of web scraping:
#     - What is web scraping?
#     - How is a webpage built? How does a computer "see" a webpage?
#     - Ethical considerations
# 2. Mapping the URLs of the webpages you want to scrape:
#     - How can we systematically go through all the webpages and scrape their content?
#         - You will learn to exploit the pattern in the URLs
# 3. Connecting to a webpage:
#     - How do we extract the HTML code behind the webpage?
# 4. Good practices of web scraping
#     - Limit the rate of your calls to the webpage
#     - Logging
#     - Handle exceptions
# 5. Exploiting the webpage's own data requests to extract data easily
#     - Use the network panel in Chrome Developer Tools to locate the data

# %% [markdown]
# ## What is web scraping?
#
# Web scraping is the practice of extracting information from websites in an automated and structured way
#
# - The internet is the biggest source of information/data you can find! [90% of the data on the internet has been created since 2016](https://blog.microfocus.com/how-much-data-is-created-on-the-internet-each-day/)
# - Web scraping unlock this new world of data possibilities
# - The biggest limitation is your own imagination!

# %% [markdown]
# #### One note:
# - Learning how to web scrape may be frustrating in the beginning
#     - It is a new way of thinking data
#     - It requires technological knowledge
# - Keep working with it!
#     - I promise you; you will master it
#     - And the internet will never be the same again

# %% [markdown]
# ## How a human sees a webpage vs. how a computer sees it

# %% [markdown]
# ### [www.jobnet.dk](https://job.jobnet.dk/CV/FindWork?Offset=0&SortValue=BestMatch)
#
# How a human sees a webpage             |  How a computer sees a webpage
# :-------------------------:|:-------------------------:
# ![](https://drive.google.com/thumbnail?id=1cbrC303j-gQnXbXyTEQBPT2xH7kgz6Cy&sz=w1000)  |  ![](https://drive.google.com/thumbnail?id=1VFlfDcJHCzbtmkpr4kvXzGecrDE7KmLY&sz=w1000)

# %% [markdown]
# ## Ethical Considerations (rule of thumbs)
# 1. Fair use: Take only the stuff you need
# 2. Be careful with copyrighted material
# 3. If a regular user can’t access it, we shouldn’t try to get it: [That is considered hacking](https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking)
# 4. If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from
# 5. LinkedIn case: [Scraping data on LinkedIn is legal](https://gizmodo.com/linkedin-scraping-data-legal-court-case-1848811335)
# 6. Don't hit it too fast: Essentially a DENIAL OF SERVICE attack (DOS); [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb)

# %% [markdown]
# <img src="https://github.com/snorreralund/images/raw/master/Sk%C3%A6rmbillede%202017-08-03%2014.46.32.png"/>

# %% [markdown]
# ## The Web Scraping Recipe
#
# Three (main) steps in scraping:
# 1. **MAPPING (this session)**: Find URLs of the webpages containing the information you want.
# 2. **DOWNLOADING (this session)**: Download the HTML of the webpages.
# 3. **PARSING (session 7)**: Extract the information from the HTML.

# %% [markdown]
# ### What browser to use?
# - Lectures and exercises are solely based on Chrome as my browser --> I recommend you to use Chrome as well.
# - All browsers (Chrome, Firefox, Safari, Edge etc.) can be used to investigate the webpages like you will learn to do here
#     - The practice might differ a bit

# %%
import requests
import time
import tqdm
import pandas as pd
import os
import json

# %% [markdown]
# # Video 6.1: Mapping URLs and downloading webpage content

# %% [markdown]
# ## 1. Mapping: How do we find the relevant URLs

# %% [markdown]
# ### Navigating websites to collect links
#
# How can you automate the navigation of links?

# %% [markdown]
# ### Building URLs using a recognizable pattern
# A nice trick is to understand how URLs are constructed to communicate with a server
#
# This will allow us to navigate the page:
#
# * / is like folders on your computer.
# * ? entails the start of a query with parameters
# * = defines a variable: e.g. page=1000 or offset=100 or showNumber=20
# * & separates different parameters.
# * \+ is html for whitespace

# %% [markdown]
# Lets look at how [www.jobindex.dk](https://www.jobindex.dk/jobsoegning) does it:
# - We simply click around and take note at how the address line changes

# %% [markdown]
# #### We want to create the URLs for the first 5 pages
# Is there a pattern in the URL that we can exploit?

# %%
links = []
for page in range(1,6,1):
    url = f'https://www.jobindex.dk/jobsoegning?page={page}'
    links.append(url)

# %%
links
# Out:
# ['https://www.jobindex.dk/jobsoegning?page=1',
#  'https://www.jobindex.dk/jobsoegning?page=2',
#  'https://www.jobindex.dk/jobsoegning?page=3',
#  'https://www.jobindex.dk/jobsoegning?page=4',
#  'https://www.jobindex.dk/jobsoegning?page=5']

# %% [markdown]
# ## 2. Connect to the webpage and *download* its content

# %% [markdown]
# ### Here is how you connect to and download the HTML of a webpage

# %%
import requests
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.4452c20e47f964c9b654.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"f8b694b397130e6606ced1d5b1b2e4aaf12ea0f2","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"maxd ...

# %% [markdown]
# #### Remember to tell who you are
# - Write your name and email in the header of the request you send to the webpage
# - Then the managers of the webpage will know you are not a malicious actor

# %%
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1', headers={'name':'Hjalte Fejerskov Boas','email':'hfb@econ.ku.dk'})

# %% [markdown]
# ### We now want to download the content of all 5 links we made earlier

# %%
list_htmls = []
for url in links:
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)

# %%
list_htmls
# Out:
# ['<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.4452c20e47f964c9b654.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"a9580d1b4e663c439d6aae4515da9281d89a2b03","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"max ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 2 ud af 677 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.4452c20e47f964c9b654.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=2" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=2" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=2" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=2&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=2" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"ef6ac0f66e86085fa0db5a9e5051cdf1f928b4ad","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 3 ud af 677 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.4452c20e47f964c9b654.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=3" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=3" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=3" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=3&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=3" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"21ad3d3b27c8d922364366a4006a18d5fc646f46","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 4 ud af 677 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.4452c20e47f964c9b654.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=4" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=4" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=4" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=4&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=4" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"cd508c77bfde5f005df8448c4c254c740271cbb4","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 5 ud af 677 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.5ea080079207ad7dd581.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.15701488e7249b2dbfe5.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.4452c20e47f964c9b654.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=5" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=5" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=5" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=5&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=5" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"e44126d49a6b41d97d3b152a66ff8d803c80ba39","lang":"da","lang_available":["da","en"],"lang_native":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":203,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{" ...

# %% [markdown]
# #### It is good practice to limit the rate of your calls to the website
# You can do that with the function `time.sleep()`

# %%
list_htmls = []
for url in tqdm.tqdm(links): #Track the time left before completing the loop
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|██████████| 5/5 [00:09<00:00,  1.82s/it]

# %% [markdown]
# # Video 6.2: Logging and handling exceptions

# %% [markdown]
# ## Logging
# Logging your web scraping activity is crucial to ensuring and demonstrating data quality. It helps you:
# - to document the data you extract
# - to understand the reasons behind any unexpected stops of your web scraper

# %% [markdown]
# ### Minimum essentials to log
# - *Time* of the scrape
# - The *status code* of the request response
#     - If succesful, the status code is normally *200*
#     - A common error is *404*: "*Page not found*"
# - The *length* of the output
#     - To indicate whether there may be a mistake
#     - In our case the output is usually some HTML code
# - The *path* to the output file
#     - What did we actually scrape?

# %% [markdown]
# #### Here is a simple logging function that you can use:

# %%
# Define the log function to gather the log information
def log(response,logfile,output_path=os.getcwd()):
    # Open or create the csv file
    if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
        log = open(logfile,'a')
    else: #If the log file does not exist, create it and make headers for the log variables
        log = open(logfile,'w')
        header = ['timestamp','status_code','length','output_file']
        log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
    # Gather log information
    status_code = response.status_code #Status code from the request result
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
    length = len(response.text) #Length of the HTML-string
    
    # Open the log file and append the gathered log information
    with open(logfile,'a') as log:
        log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n") #Append the information and jump to new line

# %% [markdown]
# #### Apply to web scrape:

# %%
list_htmls = []
logfile = 'log.csv'
for url in tqdm.tqdm(links):
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5)
    log(response,logfile)
# Out:
# 100%|██████████| 5/5 [00:08<00:00,  1.75s/it]

# %% [markdown]
# ## Handling exceptions
# When you web scrape you will encounter unexpected errors or crashes.
# Some common errors may be:
# - The URL does not exist
# - The connection to the internet stops
#
# How can we mitigate such problems?
# - The `Try/Except` block in python can help us
#     - If the computer encounter an error then it will execute the except code block instead

# %%
list_htmls = []
for url in tqdm.tqdm(links):
    try:
        response = requests.get(url)
    except Exception as e:
        print(url) #Print url
        print(e) #Print error
        with open("list_htmls", "w") as l: #Save the list_htmls as a json file to retrieve at another time
            json.dump(list_htmls, l)
        continue #Continue to next iteration of the loop
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|██████████| 5/5 [00:08<00:00,  1.72s/it]

# %% [markdown]
# # Video 6.3: The network panel

# %% [markdown]
# ## Background
# Many webpages are built dynamically
# - Each time you open up the webpage, it sends some **requests** to the server to retrieve the data that you see on the webpage

# %% [markdown]
# We can find these requests and use them!
# - We can then send them directly to the server
# - And then extract the data *before* it is written into the HTML
#     - Much more preferable: The data usually comes in a structured JSON format
#     - Makes it easy to use the data right away

# %% [markdown]
# ## The network panel in Chrome Developer Tools
# Use the **network panel** in the Chrome Developer Tools
# - The network panel monitors all uploads and downloads to and from the webpage
# - I.e., the network panel also monitors requests about data we are interested in

# %% [markdown]
# ### The network panel: [www.boligsiden.dk](https://www.boligsiden.dk/tilsalg)
# <img src="https://drive.google.com/thumbnail?id=1vGk2b1jxH1LU642-YWo1QgR3Q5vz2rQe&sz=w1000">

# %% [markdown]
# ### Which request is the one?
# 1. We want to locate an XHR ([XMLHttpRequest](https://en.wikipedia.org/wiki/XMLHttpRequest)). The XHRs transfer data between the server and the webpage
#     - Pick "*Fetch/XHR*"
# 2. Which XHR carries the information about the properties?
#     - We need to look through them all --> You can get a preview of the JSON file in "*Preview*"
# 3. When we have found the right XHR, we need to find the request URL
#     - Go to "*Headers*". Here you see the request URL

# %% [markdown]
# ### The steps:

# %% [markdown]
# #### Send the request to the server and get the data

# %%
response = requests.get('https://api.prod.bs-aws-stage.com/search/cases?addressTypes=villa%2Ccondo%2Cterraced+house%2Choliday+house%2Ccooperative%2Cfarm%2Chobby+farm%2Cfull+year+plot%2Cvilla+apartment%2Choliday+plot&per_page=50&page=1&highlighted=true&sortAscending=true&sortBy=timeOnMarket')

# %% [markdown]
# #### Convert the data to a JSON format in Python

# %%
result = response.json()

# %% [markdown]
# #### The JSON file consists of two different key-value pairs ("cases" and "links").
# #### We are only interested in the information about properties which are stored in the "cases" key-value pair

# %%
result_properties = result['cases']

# %% [markdown]
# #### Now we can easily convert the JSON file to a pandas DataFrame

# %%
data = pd.DataFrame(result_properties)

# %%
data
# Out:
#                                                _links  \
# 0   {'self': {'href': '/cases/9f380862-0d12-43ab-b...
# 1   {'self': {'href': '/cases/8b613063-8b33-4cf2-8...
# 2   {'self': {'href': '/cases/b2609d66-8643-4c0a-a...
# 3   {'self': {'href': '/cases/b8243eb1-6c57-4023-b...
# 4   {'self': {'href': '/cases/bfd90a82-b322-43f5-9...
# 5   {'self': {'href': '/cases/f9beb8f4-a83e-46d3-8...
# 6   {'self': {'href': '/cases/4072a739-7030-42f3-8...
# 7   {'self': {'href': '/cases/1b7dc94b-a78f-4e35-8...
# 8   {'self': {'href': '/cases/06257ff4-f25c-49f7-8...
# 9   {'self': {'href': '/cases/6f53feb9-9243-46fc-a...
# 10  {'self': {'href': '/cases/9731fb21-612a-4ebc-9...
# 11  {'self': {'href': '/cases/d551b27f-b69f-40b5-8...
# 12  {'self': {'href': '/cases/eda95308-57f8-4c9c-a...
# 13  {'self': {'href': '/cases/68bfc550-19cc-49c7-a...
# 14  {'self': {'href': '/cases/ed195b06-9c90-4eb9-a...
# 15  {'self': {'href': '/cases/3275689e-396b-4283-a...
# 16  {'self': {'href': '/cases/15ab135e-3505-4493-8...
# 17  {'self': {'href': '/cases/a69990d2-3c20-4f65-8...
# 18  {'self': {'href': '/cases/4d6a6532-3143-466a-a...
# 19  {'self': {'href': '/cases/c1fc32ac-9a1d-4034-b...
# 20  {'self': {'href': '/cases/4060fcd4-846b-40c3-a...
# 21  {'self': {'href': '/cases/157f9ef6-64dc-4b63-a...
# 22  {'self': {'href': '/cases/69dd54a0-9ccb-494e-9...
# 23  {'self': {'href': '/cases/4a6431c0-2547-467f-b...
# 24  {'self': {'href': '/cases/e2811d56-1e8e-49c8-b...
# 25  {'self': {'href': '/cases/e4714910-dd8d-42cc-b...
# 26  {'self': {'href': '/cases/76145746-1b73-4c52-b...
# 27  {'self': {'href': '/cases/5c369c88-2692-4916-9...
# 28  {'self': {'href': '/cases/21ebf95a-44a2-4212-9...
# 29  {'self': {'href': '/cases/5cb97bd8-714f-456e-a...
# 30  {'self': {'href': '/cases/80d9e5ff-5f43-4e42-9...
# 31  {'self': {'href': '/cases/5fcd21c2-a33c-46e4-8...
# 32  {'self': {'href': '/cases/d38c7a82-bd49-455f-a...
# 33  {'self': {'href': '/cases/044f13a7-9d75-4c5f-b...
# 34  {'self': {'href': '/cases/2f115106-230b-4be8-b...
# 35  {'self': {'href': '/cases/4909b513-6c5e-41bf-9...
# 36  {'self': {'href': '/cases/39d56805-450e-4483-9...
# 37  {'self': {'href': '/cases/8bf0a093-5bf5-4341-b...
# 38  {'self': {'href': '/cases/9e96eb1a-1ca4-4066-a...
# 39  {'self': {'href': '/cases/fd9b3533-60e9-430f-a...
# 40  {'self': {'href': '/cases/6d09025e-b4f8-414d-9...
# 41  {'self': {'href': '/cases/1d35f863-6949-433b-b...
# 42  {'self': {'href': '/cases/690baee3-961f-47e2-9...
# 43  {'self': {'href': '/cases/4968a03a-ae55-4ff4-8...
# 44  {'self': {'href': '/cases/da70005b-af12-4612-9...
# 45  {'self': {'href': '/cases/3291b620-1da4-4967-9...
# 46  {'self': {'href': '/cases/1d44cfa4-7213-4c3a-a...
# 47  {'self': {'href': '/cases/7ecf5694-cd70-4ad3-8...
# 48  {'self': {'href': '/cases/6e3d733c-91ae-4f1a-b...
# 49  {'self': {'href': '/cases/b4592178-4855-4271-a...
#
#                                               address     addressType  \
# 0   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 1   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 2   {'_links': {'self': {'href': '/addresses/0a3f5...            farm
# 3   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 4   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 5   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 6   {'_links': {'self': {'href': '/addresses/0f0b1...   holiday house
# 7   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 8   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 9   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 10  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 11  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 12  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 13  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 14  {'_links': {'self': {'href': '/addresses/2ef51...           villa
# 15  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 16  {'_links': {'self': {'href': '/addresses/19910...           condo
# 17  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 18  {'_links': {'self': {'href': '/addresses/1dfd6...            farm
# 19  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 20  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 21  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 22  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 23  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 24  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 25  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 26  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 27  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 28  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 29  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 30  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 31  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 32  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 33  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 34  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 35  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 36  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 37  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 38  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 39  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 40  {'_links': {'self': {'href': '/addresses/0a3f5...     cooperative
# 41  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 42  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 43  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 44  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 45  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 46  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 47  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 48  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 49  {'_links': {'self': {'href': '/addresses/0a3f5...            farm
#
#                                   caseID  \
# 0   9f380862-0d12-43ab-b39a-384213f03abf
# 1   8b613063-8b33-4cf2-8740-61537c91c9fb
# 2   b2609d66-8643-4c0a-a3c6-81eadbd16646
# 3   b8243eb1-6c57-4023-b8b1-cdf95f14a066
# 4   bfd90a82-b322-43f5-9136-4ea62296daa7
# 5   f9beb8f4-a83e-46d3-8779-85bea3c7b895
# 6   4072a739-7030-42f3-860d-b3d5b4c6848d
# 7   1b7dc94b-a78f-4e35-8d31-a4990f9572a5
# 8   06257ff4-f25c-49f7-8bec-a5518ead1b6b
# 9   6f53feb9-9243-46fc-a55c-dd0425d5a3e1
# 10  9731fb21-612a-4ebc-998f-4f7eef5b33c1
# 11  d551b27f-b69f-40b5-8e2f-71e245e24786
# 12  eda95308-57f8-4c9c-adf6-0dd0b9303a80
# 13  68bfc550-19cc-49c7-a3e5-5b69dd5e82e3
# 14  ed195b06-9c90-4eb9-abf3-15d2a62f2717
# 15  3275689e-396b-4283-abb2-b8542a445d1c
# 16  15ab135e-3505-4493-89e1-066c2404471e
# 17  a69990d2-3c20-4f65-8c86-e502ab0294d2
# 18  4d6a6532-3143-466a-a54a-b0f406cbfd52
# 19  c1fc32ac-9a1d-4034-b49f-3396f289346a
# 20  4060fcd4-846b-40c3-af3b-ae5115e13d71
# 21  157f9ef6-64dc-4b63-a5cd-8614bd721510
# 22  69dd54a0-9ccb-494e-920b-aee7b22fcacc
# 23  4a6431c0-2547-467f-b7e2-61622b6b4436
# 24  e2811d56-1e8e-49c8-b60b-b0e10346c402
# 25  e4714910-dd8d-42cc-b416-123e5132ea50
# 26  76145746-1b73-4c52-b995-e2220f25c5dc
# 27  5c369c88-2692-4916-9919-e96fef7dd8f1
# 28  21ebf95a-44a2-4212-9347-ed917eecb7dc
# 29  5cb97bd8-714f-456e-a2f0-2d6205d23f96
# 30  80d9e5ff-5f43-4e42-95eb-92f4bea3d99b
# 31  5fcd21c2-a33c-46e4-8ecc-9f4310c23e18
# 32  d38c7a82-bd49-455f-a730-137ae91c2b3e
# 33  044f13a7-9d75-4c5f-b160-960025ad3fb7
# 34  2f115106-230b-4be8-b2a0-d5f009eecfa3
# 35  4909b513-6c5e-41bf-9064-93c3e4b7f527
# 36  39d56805-450e-4483-9796-33ea18b9970d
# 37  8bf0a093-5bf5-4341-bdd7-2e00c9b0f883
# 38  9e96eb1a-1ca4-4066-a6ab-c72032e2313a
# 39  fd9b3533-60e9-430f-a9cf-5b3c85301070
# 40  6d09025e-b4f8-414d-9f01-0432e4b8728b
# 41  1d35f863-6949-433b-b133-3fc15468c911
# 42  690baee3-961f-47e2-9e1c-be5b5627d999
# 43  4968a03a-ae55-4ff4-8387-e18f4a06930c
# 44  da70005b-af12-4612-9e8b-eb5ba8f48010
# 45  3291b620-1da4-4967-996e-b4855bf02e45
# 46  1d44cfa4-7213-4c3a-ad27-e072a2b50a82
# 47  7ecf5694-cd70-4ad3-8b15-3b29ea5d6099
# 48  6e3d733c-91ae-4f1a-bdcc-3f9794f17c99
# 49  b4592178-4855-4271-af0b-94030a8f6cbf
#
#                                               caseUrl  \
# 0   https://alecsanderdelfs.dk/sag.aspx?mgl=2943&s...
# 1   https://alecsanderdelfs.dk/sag.aspx?mgl=2943&s...
# 2   https://www.danbolig.dk?propertyid=0140003377&...
# 3   https://www.danbolig.dk?propertyid=0350001172&...
# 4   https://www.danbolig.dk?propertyid=0350001130&...
# 5   https://www.danbolig.dk?propertyid=0350001104&...
# 6   https://www.danbolig.dk?propertyid=2840000854&...
# 7   http://www.naestvedmaegleren.dk/sag.aspx?mgl=2...
# 8                      https://home.dk/sag/1020001521
# 9   https://www.danbolig.dk?propertyid=2010000647&...
# 10  https://www.danbolig.dk?propertyid=2010000637&...
# 11  https://www.danbolig.dk?propertyid=2010000609&...
# 12         https://www.lokalbolig.dk/?sag=44-X0001387
# 13  https://www.danbolig.dk?propertyid=0140003574&...
# 14  http://www.naestvedmaegleren.dk/sag.aspx?mgl=2...
# 15  https://www.danbolig.dk?propertyid=1900001053&...
# 16  https://www.danbolig.dk?propertyid=0140003586&...
# 17                     https://home.dk/sag/7190002566
# 18  https://www.danbolig.dk?propertyid=1770000824&...
# 19  https://www.danbolig.dk?propertyid=2840000896&...
# 20  https://www.danbolig.dk?propertyid=2830000402&...
# 21  https://www.nybolig.dk/services/redirect/case/...
# 22  https://www.danbolig.dk?propertyid=0350001141&...
# 23            https://www.edc.dk/sag/?sagsnr=96903841
# 24  https://hyllenogco.dk/redirect/?caseno=2813000...
# 25  https://www.danbolig.dk?propertyid=2840000899&...
# 26  http://www.boligone.dk/sag.aspx?mgl=2737&sagsn...
# 27         https://www.lokalbolig.dk/?sag=05-X0002851
# 28  https://hyllenogco.dk/redirect/?caseno=2813000...
# 29  https://www.robinhus.dk/redirect/?caseno=NMI-0...
# 30  https://www.danbolig.dk?propertyid=3120000563&...
# 31  https://www.danbolig.dk?propertyid=1900000542&...
# 32  https://www.robinhus.dk/redirect/?caseno=NMI-0...
# 33  http://www.boligone.dk/sag.aspx?mgl=2737&sagsn...
# 34            https://www.edc.dk/sag/?sagsnr=54703590
# 35                     https://home.dk/sag/1220001351
# 36  https://www.robinhus.dk/redirect/?caseno=MAK-0...
# 37  https://www.danbolig.dk?propertyid=3030000608&...
# 38  http://www.naestvedmaegleren.dk/sag.aspx?mgl=2...
# 39  https://www.nybolig.dk/services/redirect/case/...
# 40  https://www.danbolig.dk?propertyid=3020000606&...
# 41  https://www.danbolig.dk?propertyid=2010000655&...
# 42  https://www.nybolig.dk/services/redirect/case/...
# 43  https://www.danbolig.dk?propertyid=0140003534&...
# 44  https://www.danbolig.dk?propertyid=0350001133&...
# 45  https://www.nybolig.dk/services/redirect/case/...
# 46         https://www.lokalbolig.dk/?sag=27-X0002778
# 47                     https://home.dk/sag/7190002557
# 48  https://www.danbolig.dk?propertyid=1890000623&...
# 49  https://www.danbolig.dk?propertyid=1890000372&...
#
#                                           coordinates  daysOnMarket  \
# 0   {'lat': 55.73298, 'lon': 12.5644045, 'type': '...             1
# 1   {'lat': 55.72761, 'lon': 12.548129, 'type': 'E...             2
# 2   {'lat': 55.76456, 'lon': 11.709597, 'type': 'E...             2
# 3   {'lat': 55.830124, 'lon': 12.427358, 'type': '...             2
# 4   {'lat': 55.86021, 'lon': 12.420989, 'type': 'E...             2
# 5   {'lat': 55.836994, 'lon': 12.4138365, 'type': ...             2
# 6   {'lat': 55.38533, 'lon': 11.212388, 'type': 'E...             2
# 7   {'lat': 55.229168, 'lon': 11.781715, 'type': '...             2
# 8   {'lat': 55.70498, 'lon': 12.49404, 'type': 'EP...             3
# 9   {'lat': 55.84527, 'lon': 12.27966, 'type': 'EP...             3
# 10  {'lat': 55.83524, 'lon': 12.273004, 'type': 'E...             3
# 11  {'lat': 55.84378, 'lon': 12.283553, 'type': 'E...             3
# 12  {'lat': 55.760925, 'lon': 12.572729, 'type': '...             5
# 13  {'lat': 55.720512, 'lon': 11.468945, 'type': '...             5
# 14  {'lat': 55.17926, 'lon': 11.852368, 'type': 'E...             5
# 15  {'lat': 55.581028, 'lon': 12.26559, 'type': 'E...             5
# 16  {'lat': 55.71974, 'lon': 11.7559395, 'type': '...             5
# 17  {'lat': 55.18546, 'lon': 9.572824, 'type': 'EP...             5
# 18  {'lat': 55.5519, 'lon': 12.201443, 'type': 'EP...             5
# 19  {'lat': 55.41033, 'lon': 11.32461, 'type': 'EP...             5
# 20  {'lat': 55.529892, 'lon': 11.107981, 'type': '...             5
# 21  {'lat': 55.761276, 'lon': 12.495211, 'type': '...             6
# 22  {'lat': 55.84152, 'lon': 12.426503, 'type': 'E...             6
# 23  {'lat': 57.133434, 'lon': 9.313584, 'type': 'E...             6
# 24  {'lat': 55.704433, 'lon': 12.577893, 'type': '...             6
# 25  {'lat': 55.405014, 'lon': 11.380493, 'type': '...             6
# 26  {'lat': 56.37832, 'lon': 8.57324, 'type': 'EPS...             7
# 27  {'lat': 56.03923, 'lon': 12.610645, 'type': 'E...             7
# 28  {'lat': 55.684376, 'lon': 12.585245, 'type': '...             7
# 29  {'lat': 55.485214, 'lon': 11.711549, 'type': '...             7
# 30  {'lat': 57.048115, 'lon': 9.873332, 'type': 'E...             7
# 31  {'lat': 55.588093, 'lon': 12.282289, 'type': '...             7
# 32  {'lat': 55.582882, 'lon': 12.302587, 'type': '...             8
# 33  {'lat': 56.370014, 'lon': 8.576505, 'type': 'E...             8
# 34  {'lat': 55.485733, 'lon': 10.257551, 'type': '...             8
# 35  {'lat': 55.814354, 'lon': 12.372691, 'type': '...             8
# 36  {'lat': 55.646233, 'lon': 11.822267, 'type': '...             8
# 37  {'lat': 55.43889, 'lon': 11.667122, 'type': 'E...             8
# 38  {'lat': 55.17834, 'lon': 11.647494, 'type': 'E...             8
# 39  {'lat': 55.26579, 'lon': 11.746441, 'type': 'E...             8
# 40  {'lat': 55.44451, 'lon': 11.791942, 'type': 'E...             8
# 41  {'lat': 55.86917, 'lon': 12.390844, 'type': 'E...             8
# 42  {'lat': 55.22113, 'lon': 11.761486, 'type': 'E...             8
# 43  {'lat': 55.589516, 'lon': 11.653816, 'type': '...             9
# 44  {'lat': 55.84612, 'lon': 12.438253, 'type': 'E...             9
# 45  {'lat': 55.767593, 'lon': 12.484312, 'type': '...             9
# 46  {'lat': 55.4749, 'lon': 12.160712, 'type': 'EP...             9
# 47  {'lat': 55.203667, 'lon': 9.511918, 'type': 'E...             9
# 48  {'lat': 55.2135, 'lon': 9.420377, 'type': 'EPS...             9
# 49  {'lat': 55.363945, 'lon': 9.417605, 'type': 'E...            12
#
#                                          defaultImage  \
# 0   {'imageSources': [{'size': {'height': 80, 'wid...
# 1   {'imageSources': [{'size': {'height': 80, 'wid...
# 2   {'imageSources': [{'size': {'height': 80, 'wid...
# 3   {'imageSources': [{'size': {'height': 80, 'wid...
# 4   {'imageSources': [{'size': {'height': 80, 'wid...
# 5   {'imageSources': [{'size': {'height': 80, 'wid...
# 6   {'imageSources': [{'size': {'height': 80, 'wid...
# 7   {'imageSources': [{'size': {'height': 80, 'wid...
# 8   {'imageSources': [{'size': {'height': 80, 'wid...
# 9   {'imageSources': [{'size': {'height': 80, 'wid...
# 10  {'imageSources': [{'size': {'height': 80, 'wid...
# 11  {'imageSources': [{'size': {'height': 80, 'wid...
# 12  {'imageSources': [{'size': {'height': 80, 'wid...
# 13  {'imageSources': [{'size': {'height': 80, 'wid...
# 14  {'imageSources': [{'size': {'height': 80, 'wid...
# 15  {'imageSources': [{'size': {'height': 80, 'wid...
# 16  {'imageSources': [{'size': {'height': 80, 'wid...
# 17  {'imageSources': [{'size': {'height': 80, 'wid...
# 18  {'imageSources': [{'size': {'height': 80, 'wid...
# 19  {'imageSources': [{'size': {'height': 80, 'wid...
# 20  {'imageSources': [{'size': {'height': 80, 'wid...
# 21  {'imageSources': [{'size': {'height': 80, 'wid...
# 22  {'imageSources': [{'size': {'height': 80, 'wid...
# 23  {'imageSources': [{'size': {'height': 80, 'wid...
# 24  {'imageSources': [{'size': {'height': 80, 'wid...
# 25  {'imageSources': [{'size': {'height': 80, 'wid...
# 26  {'imageSources': [{'size': {'height': 80, 'wid...
# 27  {'imageSources': [{'size': {'height': 80, 'wid...
# 28  {'imageSources': [{'size': {'height': 80, 'wid...
# 29  {'imageSources': [{'size': {'height': 80, 'wid...
# 30  {'imageSources': [{'size': {'height': 80, 'wid...
# 31  {'imageSources': [{'size': {'height': 80, 'wid...
# 32  {'imageSources': [{'size': {'height': 80, 'wid...
# 33  {'imageSources': [{'size': {'height': 80, 'wid...
# 34  {'imageSources': [{'size': {'height': 80, 'wid...
# 35  {'imageSources': [{'size': {'height': 80, 'wid...
# 36  {'imageSources': [{'size': {'height': 80, 'wid...
# 37  {'imageSources': [{'size': {'height': 80, 'wid...
# 38  {'imageSources': [{'size': {'height': 80, 'wid...
# 39  {'imageSources': [{'size': {'height': 80, 'wid...
# 40  {'imageSources': [{'size': {'height': 80, 'wid...
# 41  {'imageSources': [{'size': {'height': 80, 'wid...
# 42  {'imageSources': [{'size': {'height': 80, 'wid...
# 43  {'imageSources': [{'size': {'height': 80, 'wid...
# 44  {'imageSources': [{'size': {'height': 80, 'wid...
# 45  {'imageSources': [{'size': {'height': 80, 'wid...
# 46  {'imageSources': [{'size': {'height': 80, 'wid...
# 47  {'imageSources': [{'size': {'height': 80, 'wid...
# 48  {'imageSources': [{'size': {'height': 80, 'wid...
# 49  {'imageSources': [{'size': {'height': 80, 'wid...
#
#                                       descriptionBody  \
# 0   Velkommen til Hellerupvej 43, 3. th - en enest...
# 1   Masser af plads og masser af muligheder for at...
# 2   I skønne omgivelser tæt på smuk natur i Udby l...
# 3   Flot, moderniseret lejlighed i Birkerød!Glæd j...
# 4   Markant og lækker villa med flot udsigt til Sj...
# 5   Nær fantastisk natur og alle byens bekvemmelig...
# 6   FANTASTISK FRITIDSHUS BELIGGENDE 2 MIN. GANG F...
# 7   Nøglerne til denne skønne villa på 116 kvm kan...
# 8   Ejendommen:\nEjendommen er en flot murstenseje...
# 9   Det er en flot villa i halvandet plan, som ven...
# 10  Beliggenheden og boligen kæmper en indbyrdes k...
# 11  I dejlige omgivelser tæt på grønne områder og ...
# 12  Penthouselejlighed på 148 m² med egen privat t...
# 13  I får en nem hverdag, når I rykker til Svinnin...
# 14  Der er simpelthen så skønt på Stejlehøjen 82. ...
# 15  Denne Johan Christensen-villa blev i 2015 tota...
# 16  Velkommen til stuelejligheden på Marius Peders...
# 17  I det eftertragtede og charmerende sommerhusom...
# 18  Denne eksklusive liebhaverejendom er noget ud ...
# 19  VELKOMMEN TIL BYSKELLET 40 - DIT NYE HJEM!På B...
# 20  SKØNT SOMMERHUS BELIGGENDE PÅ FANTASTISKE REER...
# 21  Denne 2V’er er en velindrettet bolig med altan...
# 22  Er du livsnyder med hang til stråtækt romantik...
# 23  Åbent hus med tilmeldingskrav 9/8 - klik på bi...
# 24  Allerede i entréen fornemmer du, at denne lejl...
# 25  NYERE OPFØRT EJENDOM BELIGGENDE I ETABLERET OM...
# 26  Velkommen til denne charmerende villa beliggen...
# 27  Fin lejlighed i en charmerende ejendom i Helsi...
# 28  Drømmer du om en bolig med en fantastisk belig...
# 29  Charmerende landsted med moderne komfort i lan...
# 30  Velkommen til Mølholmsvej 5 – en skøn bolig me...
# 31  I Greve ligger der en populær bebyggelse med L...
# 32  Velholdt og rummelig villa beliggende i et af ...
# 33  Velkommen til Lange-Müllers Vej 4 i 7500 Holst...
# 34  Åbent hus med tilmeldingskrav 9/8 - klik på bi...
# 35  Sjældent udbudt  3 værelses stuelejlighed med ...
# 36  Velkommen til Bygmarken 42 i hyggelige Kirke S...
# 37  I et lille, lukket kvarter i Fjenneslev øst fo...
# 38  Krohaven 3 udbydes nu til salg, og her venter ...
# 39  På den anden side af Næstveds byskilt ligger d...
# 40  Denne andelsbolig byder på en skøn beliggenhed...
# 41  Arkitekten Kim Utzon har tegnet ejendommen på ...
# 42  Centralt i Næstved, nærmere bestemt på Meister...
# 43  Ugerløse er et dejligt sted for store som små,...
# 44  Søger du en mulighedsrig villa centralt i Birk...
# 45  At holde fast i livsnyderiet, selv om der er m...
# 46  Leder I efter et skønt hjem i Køge, så skal I ...
# 47  På Nørre Vilstrup Bygade 120 udbydes nu denne ...
# 48  Der er ikke mange minutters gang fra denne mul...
# 49  Frørup ligger ideelt for jer, der ønsker en ti...
#
#                                      descriptionTitle  ...  \
# 0   Gennemført 5 værelses lejlighed centralt i Hel...  ...
# 1   Det er ikke kun børnene, der trives og gror he...  ...
# 2   Flot, renoveret landejendom perfekt til hesteh...  ...
# 3             Flot, moderniseret lejlighed i Birkerød  ...
# 4   Markant og lækker villa med flot udsigt til Sj...  ...
# 5   Treværelses lejlighed i flot stand nær natur o...  ...
# 6        Fantastisk fritidshus 2. min gang fra vandet  ...
# 7   Familievenlig villa i roligt kvarter tæt på Næ...  ...
# 8   Charmerende lejlighed med direkte adgang til b...  ...
# 9   Charmerende villa for enden af lukket vej i Lynge  ...
# 10  Dobbeltmuret kvalitetsvilla med pragtfuld have...  ...
# 11  Unik, nybygget villa med skøn beliggenhed i Lynge  ...
# 12  Penthouselejlighed på 148 m² med egen privat t...  ...
# 13  Renoveret etplansvilla centralt i Svinninges h...  ...
# 14  Virkelig flot etplansvilla i familievenlige Mo...  ...
# 15              Flot istandsat kvalitetsvilla i Greve  ...
# 16  Lejlighed med perfekt planløsning, skønt udemi...  ...
# 17                                    Kelstrup Strand  ...
# 18  Flotteste liebhaverejendom med 5,3 hektar jord...  ...
# 19             Skønt etplans rækkehus i Slagelse Vest  ...
# 20  Skønt sommerhus beligggende på fantastiske Reersø  ...
# 21  Lyngby-2V’er med altan og fælles have - Tæt på...  ...
# 22                                                NaN  ...
# 23     Eksklusivt Liebhaveri med betagende havudsigt!  ...
# 24        Nyrenoveret eksklusiv lejlighed på Østerbro  ...
# 25  Nyere opført ejendom beliggende i etableret om...  ...
# 26                   Indflytningsklar villa i Ellebæk  ...
# 27                    Charmerende ejendom i Helsingør  ...
# 28  En arkitektonisk perle med 4 altaner og udsigt...  ...
# 29          SKØNT LANDSTED MED MULIGHED FOR HESTEHOLD  ...
# 30                    Moderne hjem med sjæl og charme  ...
# 31  128 m2 Lind & Risør-rækkehus i populær bebyggelse  ...
# 32  HYGGELIG FAMILIEVILLA MED GOD BELIGGENHED OG K...  ...
# 33           Velbygget villa med super god indretning  ...
# 34  Klassisk villa i moderne lys – 235 indflytning...  ...
# 35  Sjældent udbudt 3 vær. stuelejlighed med skøn ...  ...
# 36        Dejlig villa beliggende ud til åbne marker!  ...
# 37                 Velholdt etplansvilla i Fjenneslev  ...
# 38                   Flot ejendom 50 meter fra vandet  ...
# 39    Charmerende rødstensvilla lige uden for Næstved  ...
# 40  Andelsbolig i super god forening lige midt i byen  ...
# 41             Enestående Utzon-villa nær skov og eng  ...
# 42  Istandsat murermestervilla med lækkert køkken-...  ...
# 43  Indflytningsklar etplansvilla i hyggelig lands...  ...
# 44                                                NaN  ...
# 45  Villa i Lyngby til den livsnydende storfamilie...  ...
# 46                                                NaN  ...
# 47                                     Nørre Vilstrup  ...
# 48                       Landejendom i skønne Pamhule  ...
# 49         Eksklusiv lystejendom med plads til heste.  ...
#
#                                          timeOnMarket totalClickCount  \
# 0   {'current': {'days': 1}, 'total': {'days': 1, ...             328
# 1   {'current': {'days': 2}, 'total': {'days': 2, ...             716
# 2   {'current': {'days': 2}, 'total': {'days': 2, ...             669
# 3   {'current': {'days': 2}, 'total': {'days': 2, ...             114
# 4   {'current': {'days': 2}, 'total': {'days': 124...             350
# 5   {'current': {'days': 2}, 'total': {'days': 2, ...              81
# 6   {'current': {'days': 2}, 'total': {'days': 175...             345
# 7   {'current': {'days': 2}, 'total': {'days': 2, ...             315
# 8   {'current': {'days': 3}, 'total': {'days': 3, ...             167
# 9   {'current': {'days': 3}, 'total': {'days': 3, ...             371
# 10  {'current': {'days': 3}, 'total': {'days': 3, ...             226
# 11  {'current': {'days': 3}, 'total': {'days': 3, ...             370
# 12  {'current': {'days': 5}, 'total': {'days': 269...             775
# 13  {'current': {'days': 5}, 'total': {'days': 5, ...             367
# 14  {'current': {'days': 5}, 'total': {'days': 5, ...             343
# 15  {'current': {'days': 5}, 'total': {'days': 5, ...             425
# 16  {'current': {'days': 5}, 'total': {'days': 5, ...             563
# 17  {'current': {'days': 5}, 'total': {'days': 5, ...             739
# 18  {'current': {'days': 5}, 'total': {'days': 5, ...             329
# 19  {'current': {'days': 5}, 'total': {'days': 5, ...             625
# 20  {'current': {'days': 5}, 'total': {'days': 5, ...             337
# 21  {'current': {'days': 6}, 'total': {'days': 6, ...             228
# 22  {'current': {'days': 6}, 'total': {'days': 6, ...             841
# 23  {'current': {'days': 6}, 'total': {'days': 6, ...             871
# 24  {'current': {'days': 6}, 'total': {'days': 6, ...             640
# 25  {'current': {'days': 6}, 'total': {'days': 191...             634
# 26  {'current': {'days': 7}, 'total': {'days': 7, ...             405
# 27  {'current': {'days': 7}, 'total': {'days': 7, ...             272
# 28  {'current': {'days': 7}, 'total': {'days': 298...             850
# 29  {'current': {'days': 7}, 'total': {'days': 7, ...             446
# 30  {'current': {'days': 7}, 'total': {'days': 7, ...             912
# 31  {'current': {'days': 7}, 'total': {'days': 7, ...             162
# 32  {'current': {'days': 8}, 'total': {'days': 8, ...             390
# 33  {'current': {'days': 8}, 'total': {'days': 8, ...             520
# 34  {'current': {'days': 8}, 'total': {'days': 329...             289
# 35  {'current': {'days': 8}, 'total': {'days': 8, ...             255
# 36  {'current': {'days': 8}, 'total': {'days': 8, ...             255
# 37  {'current': {'days': 8}, 'total': {'days': 8, ...             381
# 38  {'current': {'days': 8}, 'total': {'days': 8, ...             451
# 39  {'current': {'days': 8}, 'total': {'days': 8, ...             560
# 40                           {'current': {'days': 8}}             630
# 41  {'current': {'days': 8}, 'total': {'days': 163...            1197
# 42  {'current': {'days': 8}, 'total': {'days': 8, ...             522
# 43  {'current': {'days': 9}, 'total': {'days': 9, ...             328
# 44  {'current': {'days': 9}, 'total': {'days': 9, ...             762
# 45  {'current': {'days': 9}, 'total': {'days': 9, ...             972
# 46  {'current': {'days': 9}, 'total': {'days': 9, ...             436
# 47  {'current': {'days': 9}, 'total': {'days': 9, ...             333
# 48  {'current': {'days': 9}, 'total': {'days': 9, ...             319
# 49  {'current': {'days': 12}, 'total': {'days': 12...             489
#
#     totalFavourites     utilitiesConnectionFee  yearBuilt  basementArea  \
# 0                 3  {'includedInPrice': None}       1903           NaN
# 1                 9  {'includedInPrice': None}       1912          68.0
# 2                10  {'includedInPrice': None}       1912           NaN
# 3                 1  {'includedInPrice': None}       1960           NaN
# 4                 1  {'includedInPrice': None}       1973          39.0
# 5                 1  {'includedInPrice': None}       1975           NaN
# 6                 6  {'includedInPrice': None}       2006           NaN
# 7                 3  {'includedInPrice': None}       1949           NaN
# 8                 2  {'includedInPrice': None}       1935           NaN
# 9                 3  {'includedInPrice': None}       1996           NaN
# 10                5  {'includedInPrice': None}       1979           NaN
# 11                2  {'includedInPrice': None}       2022           NaN
# 12                3  {'includedInPrice': None}       1924           NaN
# 13                5  {'includedInPrice': None}       1961           NaN
# 14                1  {'includedInPrice': None}       2007           NaN
# 15                5  {'includedInPrice': None}       1978           NaN
# 16                5  {'includedInPrice': None}       2007           NaN
# 17                5  {'includedInPrice': None}       1920           NaN
# 18                3  {'includedInPrice': None}       2011           NaN
# 19                3  {'includedInPrice': None}       1990           NaN
# 20                4  {'includedInPrice': None}       1972           NaN
# 21                3  {'includedInPrice': None}       1940           NaN
# 22                9  {'includedInPrice': None}       1902           NaN
# 23               17  {'includedInPrice': None}       1961          74.0
# 24                4  {'includedInPrice': None}       1895           NaN
# 25                4  {'includedInPrice': None}       2022           NaN
# 26                2  {'includedInPrice': None}       1977           NaN
# 27                3  {'includedInPrice': None}       1750           NaN
# 28                3  {'includedInPrice': None}       1957           NaN
# 29                7  {'includedInPrice': None}       1900           NaN
# 30                4  {'includedInPrice': None}       1922           NaN
# 31                3  {'includedInPrice': None}       1999           NaN
# 32                6  {'includedInPrice': None}       1969          24.0
# 33                4  {'includedInPrice': None}       1974           NaN
# 34                3  {'includedInPrice': None}       1900           6.0
# 35                2  {'includedInPrice': None}       1994           NaN
# 36                3  {'includedInPrice': None}       1974           NaN
# 37                3  {'includedInPrice': None}       1978           NaN
# 38                0  {'includedInPrice': None}       1971           NaN
# 39                1  {'includedInPrice': None}       1947          81.0
# 40                3  {'includedInPrice': None}       1894           NaN
# 41                4  {'includedInPrice': None}       2009          46.0
# 42                7  {'includedInPrice': None}       1948          74.0
# 43                7  {'includedInPrice': None}       1972           NaN
# 44               15  {'includedInPrice': None}       1958          32.0
# 45               12  {'includedInPrice': None}       1969         101.0
# 46                2  {'includedInPrice': None}       2005           NaN
# 47                0  {'includedInPrice': None}       1985           NaN
# 48                4  {'includedInPrice': None}       1924           NaN
# 49                4  {'includedInPrice': None}       1856         286.0
#
#     lotArea weightedArea                                      nextOpenHouse  \
# 0       NaN          NaN                                                NaN
# 1     790.0       150.90                                                NaN
# 2   11237.0       162.40  {'date': '2024-08-11T09:00:00Z', 'duration': 3...
# 3       NaN          NaN  {'date': '2024-08-11T08:40:00Z', 'duration': 2...
# 4    1277.0       238.00  {'date': '2024-08-18T12:45:00Z', 'duration': 3...
# 5       NaN          NaN  {'date': '2024-08-11T08:00:00Z', 'duration': 3...
# 6       NaN        89.50                                                NaN
# 7     791.0       127.90                                                NaN
# 8       NaN          NaN  {'date': '2024-08-18T10:00:00Z', 'duration': 3...
# 9     950.0       167.20  {'date': '2024-08-11T09:40:00Z', 'duration': 2...
# 10    959.0       121.80  {'date': '2024-08-11T09:00:00Z', 'duration': 3...
# 11    453.0       136.50  {'date': '2024-08-11T10:15:00Z', 'duration': 2...
# 12      NaN          NaN  {'date': '2024-08-11T10:40:00Z', 'duration': 2...
# 13    991.0       179.25  {'date': '2024-08-11T12:00:00Z', 'duration': 3...
# 14   1034.0       146.50                                                NaN
# 15    742.0       146.55                                                NaN
# 16      NaN          NaN  {'date': '2024-08-11T10:00:00Z', 'duration': 3...
# 17   2138.0        87.00                                                NaN
# 18  52975.0       216.80                                                NaN
# 19    303.0        95.10                                                NaN
# 20    957.0        81.30                                                NaN
# 21      NaN          NaN  {'date': '2024-08-11T10:35:00Z', 'duration': 2...
# 22    952.0       183.00                                                NaN
# 23  14493.0       160.80  {'date': '2024-08-09T11:00:00Z', 'duration': 2...
# 24      NaN          NaN  {'date': '2024-08-11T11:30:00Z', 'duration': 3...
# 25    825.0       337.40                                                NaN
# 26   1005.0       135.50                                                NaN
# 27      NaN          NaN  {'date': '2024-08-11T10:30:00Z', 'duration': 3...
# 28      NaN          NaN  {'date': '2024-08-11T09:00:00Z', 'duration': 3...
# 29  19995.0       198.20                                                NaN
# 30   1459.0       185.25  {'date': '2024-08-08T08:00:00Z', 'duration': 3...
# 31    140.0       128.00                                                NaN
# 32    783.0       194.40                                                NaN
# 33   1173.0       188.75  {'date': '2024-08-18T11:45:00Z', 'duration': 4...
# 34   1209.0       239.10  {'date': '2024-08-09T08:00:00Z', 'duration': 3...
# 35      NaN          NaN  {'date': '2024-08-11T09:00:00Z', 'duration': 1...
# 36    877.0       154.10                                                NaN
# 37   1194.0       137.65                                                NaN
# 38    526.0        86.90                                                NaN
# 39   1076.0       119.40  {'date': '2024-08-11T09:00:00Z', 'duration': 3...
# 40    558.0          NaN                                                NaN
# 41    840.0       218.90                                                NaN
# 42    528.0       172.20  {'date': '2024-08-11T08:00:00Z', 'duration': 3...
# 43    722.0       153.00                                                NaN
# 44    801.0       137.05  {'date': '2024-08-11T10:15:00Z', 'duration': 3...
# 45   1017.0       228.70  {'date': '2024-08-11T12:30:00Z', 'duration': 2...
# 46    357.0        89.60  {'date': '2024-08-11T10:00:00Z', 'duration': 6...
# 47   1002.0       168.95                                                NaN
# 48   2112.0       149.80                                                NaN
# 49  52620.0       584.40  {'date': '2024-08-10T09:00:00Z', 'duration': 2...
#
#                                           cooperative
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  {'maxPrice': 610000, 'mortgageMaxed': False, '...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
# [50 rows x 42 columns]

# %% [markdown]
# ## And we have the data!
